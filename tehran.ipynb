# %%
# !pip install osmpy
import osmpy
osmpy.list_queries()
# Out:
# Requirement already satisfied: osmpy in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: geojson==2.5.0 in /usr/local/lib/python3.10/dist-packages (from osmpy) (2.5.0)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from osmpy) (1.5.3)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from osmpy) (3.6.1)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.10/dist-packages (from osmpy) (2.23.0)
# Requirement already satisfied: retry in /usr/local/lib/python3.10/dist-packages (from osmpy) (0.9.2)
# Requirement already satisfied: shapely==1.7.0 in /usr/local/lib/python3.10/dist-packages (from osmpy) (1.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->osmpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->osmpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->osmpy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->osmpy) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->osmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->osmpy) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->osmpy) (1.25.2)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from retry->osmpy) (4.4.2)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/lib/python3.10/dist-packages (from retry->osmpy) (1.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->osmpy) (1.16.0)
#             name                                          docstring
# 0      Amenities           Location of amenities within a boundary
# 1  AmentiesCount    Number of amenities per type within a boundary
# 2           POIs   Location of Points of Interest within a bound...
# 3     RoadLength      Length of road by roadtype within a boundary

# %%
# %cd  drive/My\ Drive/Colab\ Notebooks/
# %ls
# Out:
# /content/drive/My Drive/Colab Notebooks
#  amenity/                                                   HandWriting/      Retina/
#  amenity-mashhad/                                           HWI.ipynb         Retina.ipynb
# 'Copy of Increase RAM Reference Notes By Techhawa .ipynb'   IDRID/            task_data_single_.npy
#  DMED/                                                      IDRID.ipynb       test/
# 'Double_side_Auction_EWA+RL (1).ipynb'                      mnist.ipynb       Untitled0.ipynb
#  Double_side_Auction_EWA+RL.ipynb                           Ophtha_EX/        Untitled1.ipynb
#  Drive.ipynb                                                Ophtha_ex.ipynb   Untitled2.ipynb
#  ESAI4.ipynb                                                PlotNeuralNet/    Untitled3.ipynb

# %%
import pandas as pd
import osmpy
from shapely import wkt


# kol mashhad
boundary = wkt.loads('POLYGON((59.4201994 36.1845764,59.7237396 36.1845764,59.7237396 36.4989467,59.4201994 36.4989467,59.4201994 36.1845764))')
all = osmpy.get('Amenities', boundary)

df = pd.DataFrame(all)
df.to_csv('/content/drive/My Drive/Colab Notebooks/amenity/all.csv')

RoadLength = osmpy.get('RoadLength', boundary)
print(RoadLength)

AmentiesCount = osmpy.get('AmentiesCount', boundary)
print(AmentiesCount)

df = pd.DataFrame(RoadLength)
df.to_csv('/content/drive/My Drive/Colab Notebooks/amenity/all-RoadLength.csv')

df = pd.DataFrame(AmentiesCount)
df.to_csv('/content/drive/My Drive/Colab Notebooks/amenity/all-AmentiesCount.csv')

# %%
import osmpy
import requests
import pandas as pd
from shapely import wkt
from shapely.geometry import Polygon

relation_ids = [6728830, 6728896, 6728897, 6728863, 6729507, 6729037, 6729036,
                6729035, 6729508, 6729501, 6729111, 6729112, 6729034, 6729033,
                6729032, 6729110, 6729502, 6729503, 6729109, 6729031, 6729505, 6729506]

for relation_id in relation_ids:

    # Define the Overpass API query to retrieve the relation data
    overpass_url = "https://overpass-api.de/api/interpreter"
    query = f"""
    [out:json];
    relation({relation_id});
    out geom;
    """

    # Send the query to the Overpass API
    response = requests.get(overpass_url, params={"data": query})
    data = response.json()

    # Process the relation data
    if "elements" in data:
        relation = data["elements"][0]  # Assuming the relation is the first element in the response

        # df = pd.DataFrame([relation])
        # df.to_csv(str(relation_id) + '.csv')

        name = relation['tags']['name']
        bounding_box = relation['bounds']
        print(name, "Relation Bounds:", bounding_box)

        # Create a polygon from the bounding box coordinates
        polygon = Polygon([
            (bounding_box['minlon'], bounding_box['minlat']),
            (bounding_box['maxlon'], bounding_box['minlat']),
            (bounding_box['maxlon'], bounding_box['maxlat']),
            (bounding_box['minlon'], bounding_box['maxlat']),
            (bounding_box['minlon'], bounding_box['minlat'])
        ])

        # Print the polygon as a WKT string
        # print(polygon.wkt)

        boundary = wkt.loads(polygon.wkt)
        relation_boundary = osmpy.get('Amenities', boundary)

        try:
            RoadLength = osmpy.get('RoadLength', boundary)
            # print(RoadLength)
            df = pd.DataFrame(RoadLength)
            df.to_csv(
                '/content/drive/My Drive/Colab Notebooks/amenity/' + name + '-' + str(relation_id) + '-RoadLength.csv')
        except:
            pass

        try:
            AmentiesCount = osmpy.get('AmentiesCount', boundary)
            # print(AmentiesCount)
            df = pd.DataFrame(AmentiesCount)
            df.to_csv('/content/drive/My Drive/Colab Notebooks/amenity/' + name + '-' + str(
                relation_id) + '-AmentiesCount.csv')
        except:
            pass

        df = pd.DataFrame(relation_boundary)
        df.to_csv('/content/drive/My Drive/Colab Notebooks/amenity/' + name + '-' + str(relation_id) + '.csv')

    else:
        print("Relation not found.")
# Out:
# منطقه ۱ شهر تهران Relation Bounds: {'minlat': 35.7773022, 'minlon': 51.3751797, 'maxlat': 35.8284702, 'maxlon': 51.5392015}
# منطقه ۲ شهر تهران Relation Bounds: {'minlat': 35.6998016, 'minlon': 51.331781, 'maxlat': 35.8037497, 'maxlon': 51.393135}
# منطقه ۳ شهر تهران Relation Bounds: {'minlat': 35.7402429, 'minlon': 51.3860821, 'maxlat': 35.7938099, 'maxlon': 51.4764252}
# منطقه ۴ شهر تهران Relation Bounds: {'minlat': 35.723535, 'minlon': 51.4468891, 'maxlat': 35.790468, 'maxlon': 51.6063007}
# منطقه ۵ شهر تهران Relation Bounds: {'minlat': 35.6966811, 'minlon': 51.2620291, 'maxlat': 35.8100343, 'maxlon': 51.3419282}
# منطقه ۶ شهر تهران Relation Bounds: {'minlat': 35.7006576, 'minlon': 51.377614, 'maxlat': 35.7521851, 'maxlon': 51.4275001}
# منطقه ۷ شهر تهران Relation Bounds: {'minlat': 35.70167, 'minlon': 51.4203466, 'maxlat': 35.7426959, 'maxlon': 51.4722863}
# منطقه ۸ شهر تهران Relation Bounds: {'minlat': 35.7090256, 'minlon': 51.4588739, 'maxlat': 35.7403457, 'maxlon': 51.5385939}
# منطقه ۹ شهر تهران Relation Bounds: {'minlat': 35.6664088, 'minlon': 51.2786964, 'maxlat': 35.7020419, 'maxlon': 51.3564956}
# منطقه ۱۰ شهر تهران Relation Bounds: {'minlat': 35.6670146, 'minlon': 51.3522072, 'maxlat': 35.7006576, 'maxlon': 51.3815441}
# منطقه ۱۱ شهر تهران Relation Bounds: {'minlat': 35.6584185, 'minlon': 51.3781086, 'maxlat': 35.7013858, 'maxlon': 51.4128702}
# منطقه ۱۲ شهر تهران Relation Bounds: {'minlat': 35.6580886, 'minlon': 51.4048972, 'maxlat': 35.7019892, 'maxlon': 51.4480975}
# منطقه ۱۳ شهر تهران Relation Bounds: {'minlat': 35.6895984, 'minlon': 51.4473525, 'maxlat': 35.7262284, 'maxlon': 51.598903}
# منطقه ۱۴ شهر تهران Relation Bounds: {'minlat': 35.6441634, 'minlon': 51.4456059, 'maxlat': 35.6929613, 'maxlon': 51.5232467}
# منطقه ۱۵ شهر تهران Relation Bounds: {'minlat': 35.6057444, 'minlon': 51.4309977, 'maxlat': 35.6654069, 'maxlon': 51.5122269}
# منطقه ۱۶ شهر تهران Relation Bounds: {'minlat': 35.6144292, 'minlon': 51.3820957, 'maxlat': 35.6596229, 'maxlon': 51.4363541}
# منطقه ۱۷ شهر تهران Relation Bounds: {'minlat': 35.6366579, 'minlon': 51.343868, 'maxlat': 35.6708457, 'maxlon': 51.3822754}
# منطقه ۱۸ شهر تهران Relation Bounds: {'minlat': 35.6200969, 'minlon': 51.2304534, 'maxlat': 35.683573, 'maxlon': 51.356563}
# منطقه ۱۹ شهر تهران Relation Bounds: {'minlat': 35.6074271, 'minlon': 51.3248439, 'maxlat': 35.6553849, 'maxlon': 51.4047147}
# منطقه ۲۰ شهر تهران Relation Bounds: {'minlat': 35.5682071, 'minlon': 51.4002501, 'maxlat': 35.6295415, 'maxlon': 51.4721365}
# منطقه ۲۱ شهر تهران Relation Bounds: {'minlat': 35.6767414, 'minlon': 51.0890493, 'maxlat': 35.7456386, 'maxlon': 51.2914947}
# منطقه ۲۲ شهر تهران Relation Bounds: {'minlat': 35.7145052, 'minlon': 51.0901497, 'maxlat': 35.7714209, 'maxlon': 51.2911501}

# %%
import json
import requests
import pandas as pd
from shapely import wkt
from shapely.geometry import Polygon

relation_ids = [5710706, 5711010, 5711407, 5711567, 5712345, 5714586, 5714602, 5714616, 5722613, 5724225,
                5724306, 5725071, 5725072, 8863117, 8863118, 9042658, 9042659, 9042653, 9042654, 9042650,
                9042651, 9042652, 8834223, 8834224, 8834225, 8834226, 8834227, 9068587, 8810327, 8810328,
                8810329, 8810330, 8873128, 8873129, 9042655, 9042656, 9042657, 9042648, 9042649, 8873125,
                8873126, 8873127, 9042646, 9042660, 9042661, 8873134, 8873135, 8873136, 8873130, 8873131,
                8873132, 8873133, 8796705, 8796706, 8796707, 8796708, 8796694, 8796698, 8796699, 8796700,
                10235671, 8796695, 8796696, 8796701, 8796702, 10374714, 10374716, 8796697, 8796703, 8796704,
                11009418, 8785942, 8785943, 8785944, 8785946, 8785947, 8785948, 8785945, 8785949, 8785950,
                8785951, 8785952, 8824631, 8824632, 8824633, 8824629, 8824630, 8824634, 8824635, 8824636,
                8824637, 8824638, 8824639, 8824640, 8824641, 8824642, 8824643, 8824644, 8824645, 8824646,
                8824866, 8824867, 8824868, 8824869, 8824870, 9068585, 9068586, 8824871, 8824872, 8824873,
                8824874, 8824875, 8824876, 8792420, 8792421, 8792422, 8792423, 8792424, 8792425, 8792426,
                8788794, 8792427, 8788795, 8788796, 8788797, 8788798, 8788799, 8788800, 8788801, 8788802,
                8788803, 8788804, 8788805, 8788806, 8788807, 8788808, 11009422, 11009423, 11009424, 11009428,
                11009429, 11009430, 11009431, 11009432, 11009433, 11009435, 8810560, 8810561, 8810562, 8810563,
                8810557, 8810558, 8810559, 8810554, 8810555, 8810556, 8833948, 8833949, 8833659, 8833660,
                8833661, 8833662, 8833663, 8833664, 11248722, 8833665, 8833666, 8833667, 8833668, 8833669,
                8833670, 10374717, 10374718, 8815020, 8815673, 8815674, 8815675, 8815676, 8815662, 8815668,
                8815669, 8815670, 8815671, 8815672, 8815663, 8815664, 8815665, 8815666, 8815667, 8815016,
                8815017, 8815018, 8815019, 8815020, 8815021, 8815013, 8815014, 8815015, 10776078, 8833775,
                8833777, 8833778, 8833779, 11248723, 8833768, 8833769, 8833770, 8833771, 11248724, 8833772,
                8833773, 8833774, 8833776, 8833839, 8833840, 8833841, 8833842, 8833843, 8833844, 8833845,
                8833846, 8833847, 8833950, 9042642, 8833947, 9042643, 9042644, 9042645]


features = []

for relation_id in relation_ids:
    # relation_id = 5725071

    # Define the Overpass API query to retrieve the relation data
    overpass_url = "https://overpass-api.de/api/interpreter"
    query = f"""
    [out:json];
    relation({relation_id});
    out geom;
    """

    # Send the query to the Overpass API
    response = requests.get(overpass_url, params={"data": query})
    data = response.json()

    # Process the relation data
    # if "elements" in data:
    try:
        relation = data["elements"][0]
        name = relation['tags']['name']
        geometry = relation['members'][0]['geometry']

        coordinates = []
        for geo in geometry:
            coordinates.append([geo['lat'], geo['lon']])

        features.append({
            "type": "Feature",
            "id": str(relation_id),
            "properties": {
                "name": name,
                "density": 94.65
            },
            "geometry": {
                "type": "Polygon",
                "coordinates": [coordinates]
            }
        })

    except:
        print("Relation not found.")


staticdata = {
    "type": "FeatureCollection",
    "features": features
}
print(staticdata)

json_data = json.dumps(staticdata)
print(json_data)

with open("data.json", "w") as file:
    file.write(json_data)

# %%
import os

import numpy as np
import pandas as pd

import shapely
from shapely.geometry.polygon import Polygon
# from shapely import Polygon, wkt

category = [{'public transport': ['bureau_de_change', 'bus_station', 'car_sharing', 'busway', 'road', 'track',
                                  'motorway', 'path', 'motorcycle_parking', 'parking', 'car_rental', 'corridor',
                                  'taxi', 'fuel', 'parking_entrance']},
            {'cycling infrastructure': ['bicycle_parking', 'bicycle_rental', 'cycleway']},
            {'sidewalks': ['footway', 'pedestrian']},
            {'residential': ['residential']},
            {'public safety': ['fire_station', 'police']},
            {'commercial': ['atm', 'bank', 'register_office', 'post_box', 'post_office', 'marketplace',
                            'vending_machine']},
            {'educational': ['college', 'university', 'driving_school', 'school', 'kindergarten', 'music_school']},
            {'recreational': ['cafe', 'cinema', 'fast_food', 'restaurant', 'ice_cream', 'food_court', 'rest_area',
                              'drinking_water', 'internet_cafe', 'library', 'place_of_worship', 'social_centre',
                              'service', 'social_facility', 'theatre', 'toilets', 'townhall', 'waste_basket',
                              'waste_disposal']},
            {'healthcare': ['dentist', 'doctors', 'clinic', 'pharmacy', 'hospital', 'veterinary']}]

keywords = ['atm', 'bureau_de_change', 'bus_station', 'car_sharing', 'busway', 'road', 'track',
            'motorway', 'path', 'motorcycle_parking', 'parking', 'car_rental', 'corridor', 'vending_machine'
            'taxi', 'fuel', 'parking_entrance', 'bicycle_parking', 'bicycle_rental', 'music_school'
            'cycleway', 'footway', 'pedestrian', 'residential', 'fire_station', 'police', 'bank', 'register_office',
            'post_box', 'post_office', 'college', 'university', 'driving_school', 'school', 'kindergarten',
            'cafe', 'cinema', 'fast_food', 'restaurant', 'ice_cream', 'food_court', 'rest_area',
            'drinking_water', 'internet_cafe', 'library', 'place_of_worship', 'social_centre', 'service',
            'social_facility', 'theatre', 'toilets', 'townhall', 'waste_basket', 'waste_disposal', 'marketplace',
            'dentist', 'doctors', 'clinic', 'pharmacy', 'hospital', 'veterinary']

results = {}
count = []

for path, subdirs, files in os.walk('/content/drive/MyDrive/Colab Notebooks/amenity/'):
    for i in range(len(files)):
        try:
            key = files[i].split('-')[0]
            # print(files[i].split('-')[0])
            name = files[i].split('-')[2]

            a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amenity/' + files[i])

            if name == 'AmentiesCount.csv':
                name = 'amenity'
            elif name == 'RoadLength.csv':
                name = 'highway'

            common_amenities = [{keywords[i]: a['count'].iloc[a[name].to_list().index(keywords[i])]}
                                for i in range(len(keywords))
                                if keywords[i] in a[name].to_list()]
            # print(common_amenities)

            count = []

            for i, cat in enumerate(category):
                cat_count = 0
                for amenity in common_amenities:
                    if list(amenity.keys())[0] in list(cat.values())[0]:
                        cat_count += list(amenity.values())[0]
                count.append(cat_count)

            item = results.get(key)
            if item is not None:
                count = [c + i for c, i in zip(count, item)]

            total_count = len(count)
            percentage = (sum(1 for c in count if c >= 1) / total_count) * 100
            count.append(round(percentage, 2))

            results.__setitem__(key, count)

        except:
            pass

# categories = ['zone']
categories = [list(dic.keys())[0] for dic in category]
categories.append('percentage')

df = pd.DataFrame(results, index=categories)
df = df.transpose()

total_results = len(results)
percentages = []
for key in categories:
    percentages.append(round((sum(1 for res in df[key] if res >= 1) / total_results) * 100, 2))

percentages.pop()
percentages.append(np.mean(df['percentage']))
results.__setitem__('percentage', percentages)

df = pd.DataFrame(results, columns=results.keys(), index=categories)
df.to_csv('results-tehran.csv', encoding='utf-8')


import json
import requests
import pandas as pd

relation_ids = [6728830, 6728896, 6728897, 6728863, 6729507, 6729037, 6729036,
                6729035, 6729508, 6729501, 6729111, 6729112, 6729034, 6729033,
                6729032, 6729110, 6729502, 6729503, 6729109, 6729031, 6729505, 6729506]


features = []
for relation_id in relation_ids:
    overpass_url = "https://overpass-api.de/api/interpreter"
    query = f"""
    [out:json];
    relation({relation_id});
    out geom;
    """

    response = requests.get(overpass_url, params={"data": query})
    data = response.json()

    try:
        relation = data["elements"][0]
        name = relation['tags']['name']
        geometry = relation['members'][0]['geometry']
        # print(geometry)
        percentage = df[name].iloc[-1]


        coordinates = []
        for geo in geometry:
            coordinates.append([geo['lat'], geo['lon']])
        # coordinates.append([geometry[0]['lat'], geometry[0]['lon']])
        # print(coordinates)

        # polygon = Polygon(coordinates)
        # Print the polygon as a WKT string
        # print(polygon.wkt)
        # boundary = wkt.loads(polygon.wkt)
        # print(polygon.wkt)

        features.append({
            "type": "Feature",
            "id": str(relation_id),
            "properties": {
                "name": name,
                "amenity": percentage
            },
            "geometry": {
                "type": "Polygon",
                "coordinates": [[coordinates]]
            }
        })

    except:
        print("Relation not found.")


staticdata = {
    "type": "FeatureCollection",
    "features": features
}
print(staticdata)

json_data = json.dumps(staticdata)
print(json_data)

with open("data.json", "w") as file:
    file.write(json_data)

with open("staticdata.json", "w") as file:
    file.write(staticdata)
# Out:
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# Relation not found.
# {'type': 'FeatureCollection', 'features': []}
# {"type": "FeatureCollection", "features": []}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ca83cb4aade5> in <cell line: 170>()
#     169
#     170 with open("staticdata.json", "w") as file:
# --> 171     file.write(staticdata)
#
# TypeError: write() argument must be str, not dict

# %%
import json
import requests
import pandas as pd
from geojson import MultiPolygon

relation_id = 5725142
features = []
overpass_url = "https://overpass-api.de/api/interpreter"
query = f"""
[out:json];
relation({relation_id});
out geom;
"""

response = requests.get(overpass_url, params={"data": query})
data = response.json()


relation = data["elements"][0]
name = relation['tags']['name']
geometry = relation['members'][0]['geometry']
# print(geometry)
# percentage = df[name].iloc[-1]

coordinates = []
for geo in geometry:
    # coordinates.append([geo['lon'], geo['lat']])
    coordinates.append((geo['lat'], geo['lon']))

x = MultiPolygon([(coordinates)])
print(x)
# coordinates.append([geometry[0]['lat'], geometry[0]['lon']])
# print(coordinates)

# polygon = Polygon(coordinates)
# Print the polygon as a WKT string
# print(polygon.wkt)
# boundary = wkt.loads(polygon.wkt)
# print(polygon.wkt)



features.append({
    "type": "Feature",
    "id": str(relation_id),
    "properties": {
        "name": name,
        "amenity": 100
    },
    "geometry": {
        "type": "Polygon",
        "coordinates": [[coordinates]]
    }
})


staticdata = {
    "type": "FeatureCollection",
    "features": features
}
print(staticdata)

json_data = json.dumps(staticdata)
print(json_data)

with open("data.json", "w") as file:
    file.write(json_data)

with open("staticdata.json", "w") as file:
    file.write(staticdata)
# Out:
# {"coordinates": [[[36.39322, 59.680303], [36.393626, 59.680268], [36.394067, 59.680355], [36.394402, 59.680349], [36.395175, 59.680372], [36.396316, 59.68042], [36.396606, 59.680377], [36.396841, 59.680347], [36.397834, 59.680081], [36.398881, 59.679563], [36.399445, 59.679201], [36.399419, 59.679862], [36.399458, 59.679984], [36.400029, 59.680037], [36.400481, 59.679602], [36.40117, 59.680363], [36.400556, 59.681194], [36.400946, 59.681887], [36.401223, 59.683202], [36.402395, 59.682971], [36.402617, 59.68034], [36.401874, 59.67907], [36.402393, 59.678262], [36.403806, 59.6778], [36.403841, 59.67683], [36.40572, 59.676876], [36.406684, 59.676853]]], "type": "MultiPolygon"}
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': '5725142', 'properties': {'name': 'شهر مشهد', 'amenity': 100}, 'geometry': {'type': 'Polygon', 'coordinates': [[[(36.3932195, 59.6803034), (36.3936259, 59.6802683), (36.3940672, 59.6803546), (36.3944025, 59.6803493), (36.3951747, 59.6803716), (36.3963155, 59.6804202), (36.3966061, 59.6803772), (36.3968406, 59.6803466), (36.3978344, 59.6800805), (36.3988807, 59.679563), (36.3994448, 59.6792007), (36.3994192, 59.679862), (36.3994584, 59.6799844), (36.4000286, 59.6800375), (36.4004814, 59.6796018), (36.4011695, 59.6803635), (36.4005558, 59.6811944), (36.4009463, 59.6818869), (36.4012231, 59.6832021), (36.4023947, 59.6829713), (36.4026174, 59.6803397), (36.4018735, 59.6790702), (36.402393, 59.6782619), (36.4038064, 59.6778003), (36.4038415, 59.67683), (36.4057197, 59.6768762), (36.4066841, 59.6768525)]]]}}]}
# {"type": "FeatureCollection", "features": [{"type": "Feature", "id": "5725142", "properties": {"name": "\u0634\u0647\u0631 \u0645\u0634\u0647\u062f", "amenity": 100}, "geometry": {"type": "Polygon", "coordinates": [[[[36.3932195, 59.6803034], [36.3936259, 59.6802683], [36.3940672, 59.6803546], [36.3944025, 59.6803493], [36.3951747, 59.6803716], [36.3963155, 59.6804202], [36.3966061, 59.6803772], [36.3968406, 59.6803466], [36.3978344, 59.6800805], [36.3988807, 59.679563], [36.3994448, 59.6792007], [36.3994192, 59.679862], [36.3994584, 59.6799844], [36.4000286, 59.6800375], [36.4004814, 59.6796018], [36.4011695, 59.6803635], [36.4005558, 59.6811944], [36.4009463, 59.6818869], [36.4012231, 59.6832021], [36.4023947, 59.6829713], [36.4026174, 59.6803397], [36.4018735, 59.6790702], [36.402393, 59.6782619], [36.4038064, 59.6778003], [36.4038415, 59.67683], [36.4057197, 59.6768762], [36.4066841, 59.6768525]]]]}}]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f939f64a5d81> in <cell line: 69>()
#      68
#      69 with open("staticdata.json", "w") as file:
# ---> 70     file.write(staticdata)
#
# TypeError: write() argument must be str, not dict

# %%
# !pip install geojson
# Out:
# Collecting geojson
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.0.1

# %%
import os

import numpy as np
import pandas as pd

import shapely
from shapely.geometry.polygon import Polygon

# from shapely import Polygon, wkt
import requests

category = [{'public transport': ['bureau_de_change', 'bus_station', 'car_sharing', 'busway', 'road', 'track',
                                  'motorway', 'path', 'motorcycle_parking', 'parking', 'car_rental', 'corridor',
                                  'taxi', 'fuel', 'parking_entrance']},
            {'cycling infrastructure': ['bicycle_parking', 'bicycle_rental', 'cycleway']},
            {'sidewalks': ['footway', 'pedestrian']},
            {'residential': ['residential']},
            {'public safety': ['fire_station', 'police']},
            {'commercial': ['atm', 'bank', 'register_office', 'post_box', 'post_office', 'marketplace',
                            'vending_machine']},
            {'educational': ['college', 'university', 'driving_school', 'school', 'kindergarten', 'music_school']},
            {'recreational': ['cafe', 'cinema', 'fast_food', 'restaurant', 'ice_cream', 'food_court', 'rest_area',
                              'drinking_water', 'internet_cafe', 'library', 'place_of_worship', 'social_centre',
                              'service', 'social_facility', 'theatre', 'toilets', 'townhall', 'waste_basket',
                              'waste_disposal']},
            {'healthcare': ['dentist', 'doctors', 'clinic', 'pharmacy', 'hospital', 'veterinary']}]

keywords = ['atm', 'bureau_de_change', 'bus_station', 'car_sharing', 'busway', 'road', 'track',
            'motorway', 'path', 'motorcycle_parking', 'parking', 'car_rental', 'corridor', 'vending_machine'
            'taxi', 'fuel', 'parking_entrance', 'bicycle_parking', 'bicycle_rental', 'music_school'
            'cycleway', 'footway', 'pedestrian', 'residential', 'fire_station', 'police', 'bank', 'register_office',
            'post_box', 'post_office', 'college', 'university', 'driving_school', 'school', 'kindergarten',
            'cafe', 'cinema', 'fast_food', 'restaurant', 'ice_cream', 'food_court', 'rest_area',
            'drinking_water', 'internet_cafe', 'library', 'place_of_worship', 'social_centre', 'service',
            'social_facility', 'theatre', 'toilets', 'townhall', 'waste_basket', 'waste_disposal', 'marketplace',
            'dentist', 'doctors', 'clinic', 'pharmacy', 'hospital', 'veterinary']

results = {}
count = []

for path, subdirs, files in os.walk('/content/drive/MyDrive/Colab Notebooks/amenity/'):
    for i in range(len(files)):
        try:
            key = files[i].split('-')[0]
            relation_id = files[i].split('-')[1]
            name = files[i].split('-')[2]
            # print(files[i])
            a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amenity/' + files[i])

            if name == 'AmentiesCount.csv':
                name = 'amenity'
            elif name == 'RoadLength.csv':
                name = 'highway'

            common_amenities = [{keywords[i]: a['count'].iloc[a[name].to_list().index(keywords[i])]}
                                for i in range(len(keywords))
                                if keywords[i] in a[name].to_list()]
            # print(common_amenities)

            count = []

            for i, cat in enumerate(category):
                cat_count = 0
                for amenity in common_amenities:
                    if list(amenity.keys())[0] in list(cat.values())[0]:
                        cat_count += list(amenity.values())[0]
                count.append(cat_count)

            item = results.get(key)
            if item is not None:
                count = [c + i for c, i in zip(count, item)]

            total_count = len(count)
            percentage = (sum(1 for c in count if c >= 1) / total_count) * 100
            count.append(round(percentage, 2))
            # print(key, count)

            # try:
            #     overpass_url = "https://overpass-api.de/api/interpreter"
            #     query = f"""
            #     [out:json];
            #     relation({relation_id});
            #     out geom;
            #     """

            #     response = requests.get(overpass_url, params={"data": query})
            #     res = response.json()
            #     relation = res["elements"][0]

            #     geometry = relation['members'][0]['geometry']
            #     count.append(geometry)
            #     print(key, geometry)
            # except exp:
            #   print(exp)
            count.append([])

            print(key, count)
            results.__setitem__(key, count)

        except:
            pass

# categories = ['zone']
categories = [list(dic.keys())[0] for dic in category]
categories.append('percentage')
categories.append('coordinates')

df = pd.DataFrame(results, index=categories)
df = df.transpose()

total_results = len(results)
percentages = []
for key in categories:
    try:
        percentages.append(round((sum(1 for res in df[key] if res >= 1) / total_results) * 100, 2))
    except:
        percentages.append(0)

percentages.pop()
percentages.append(np.mean(df['percentage']))
results.__setitem__('percentage', percentages)

df = pd.DataFrame(results, columns=results.keys(), index=categories)
df = df.transpose()
# print(results)
# print(df.head())
# df.to_html('results.html')
df.to_csv('results-tehron.csv', encoding='utf-8')
# df.to_excel('results.xlsx')
# Out:
# منطقه ۱ شهر تهران [134, 0, 1340, 5947, 0, 0, 0, 1235, 0, 44.44, []]
# منطقه ۱ شهر تهران [220, 1, 1340, 5947, 24, 596, 75, 1959, 404, 100.0, []]
# منطقه ۲ شهر تهران [80, 0, 2531, 4651, 0, 0, 0, 1903, 0, 44.44, []]
# منطقه ۲ شهر تهران [144, 11, 2531, 4651, 20, 386, 104, 2547, 412, 100.0, []]
# منطقه ۳ شهر تهران [29, 0, 1316, 4468, 0, 0, 0, 1198, 0, 44.44, []]
# منطقه ۳ شهر تهران [105, 1, 1316, 4468, 22, 752, 72, 1852, 597, 100.0, []]
# منطقه ۴ شهر تهران [20, 0, 1432, 7598, 0, 0, 0, 1307, 0, 44.44, []]
# منطقه ۴ شهر تهران [69, 5, 1432, 7598, 26, 465, 155, 1928, 416, 100.0, []]
# منطقه ۵ شهر تهران [89, 0, 2216, 4785, 0, 0, 0, 1202, 0, 44.44, []]
# منطقه ۵ شهر تهران [129, 5, 2216, 4785, 19, 248, 84, 1599, 214, 100.0, []]
# منطقه ۶ شهر تهران [36, 0, 1113, 1835, 0, 0, 0, 853, 0, 44.44, []]
# منطقه ۶ شهر تهران [73, 5, 1113, 1835, 18, 456, 85, 1482, 270, 100.0, []]
# منطقه ۷ شهر تهران [21, 0, 596, 4259, 0, 0, 0, 348, 0, 44.44, []]
# منطقه ۷ شهر تهران [51, 1, 596, 4259, 15, 288, 62, 646, 141, 100.0, []]
# منطقه ۸ شهر تهران [17, 0, 512, 4164, 0, 0, 0, 157, 0, 44.44, []]
# منطقه ۸ شهر تهران [25, 9, 512, 4164, 11, 244, 77, 407, 167, 100.0, []]
# منطقه ۹ شهر تهران [18, 0, 624, 1752, 0, 0, 0, 1028, 0, 44.44, []]
# منطقه ۹ شهر تهران [36, 2, 624, 1752, 6, 75, 19, 1109, 37, 100.0, []]
# منطقه ۱۰ شهر تهران [23, 0, 410, 2904, 0, 0, 0, 1577, 0, 44.44, []]
# منطقه ۱۰ شهر تهران [33, 2, 410, 2904, 6, 115, 25, 1661, 82, 100.0, []]
# منطقه ۱۱ شهر تهران [32, 0, 641, 2076, 0, 0, 0, 2854, 0, 44.44, []]
# منطقه ۱۱ شهر تهران [49, 4, 641, 2076, 17, 177, 23, 3054, 54, 100.0, []]
# منطقه ۱۲ شهر تهران [28, 0, 1176, 4650, 0, 0, 0, 1159, 0, 44.44, []]
# منطقه ۱۲ شهر تهران [68, 0, 1176, 4650, 24, 250, 42, 1487, 47, 88.89, []]
# منطقه ۱۳ شهر تهران [26, 0, 583, 4743, 0, 0, 0, 546, 0, 44.44, []]
# منطقه ۱۳ شهر تهران [43, 5, 583, 4743, 6, 187, 84, 754, 125, 100.0, []]
# منطقه ۱۴ شهر تهران [9, 0, 1119, 6138, 0, 0, 0, 805, 0, 44.44, []]
# منطقه ۱۴ شهر تهران [19, 1, 1119, 6138, 9, 127, 49, 936, 90, 100.0, []]
# منطقه ۱۵ شهر تهران [36, 0, 1656, 5807, 0, 0, 0, 340, 0, 44.44, []]
# منطقه ۱۵ شهر تهران [61, 0, 1656, 5807, 13, 117, 36, 488, 70, 88.89, []]
# منطقه ۱۶ شهر تهران [14, 0, 965, 3536, 0, 0, 0, 342, 0, 44.44, []]
# منطقه ۱۶ شهر تهران [32, 0, 965, 3536, 4, 63, 29, 468, 40, 88.89, []]
# منطقه ۱۷ شهر تهران [6, 0, 393, 2642, 0, 0, 0, 151, 0, 44.44, []]
# منطقه ۱۷ شهر تهران [31, 1, 393, 2642, 7, 85, 49, 269, 47, 100.0, []]
# منطقه ۱۸ شهر تهران [47, 0, 1114, 4290, 0, 0, 0, 625, 0, 44.44, []]
# منطقه ۱۸ شهر تهران [99, 3, 1114, 4290, 16, 124, 49, 795, 63, 100.0, []]
# منطقه ۱۹ شهر تهران [11, 0, 935, 3987, 0, 0, 0, 447, 0, 44.44, []]
# منطقه ۱۹ شهر تهران [37, 2, 935, 3987, 10, 74, 53, 608, 46, 100.0, []]
# منطقه ۲۰ شهر تهران [36, 0, 1005, 3366, 0, 0, 0, 300, 0, 44.44, []]
# منطقه ۲۰ شهر تهران [50, 0, 1005, 3366, 8, 54, 31, 402, 39, 88.89, []]
# منطقه ۲۱ شهر تهران [51, 0, 1333, 4064, 0, 0, 0, 1739, 0, 44.44, []]
# منطقه ۲۱ شهر تهران [88, 4, 1333, 4064, 19, 109, 35, 1900, 51, 100.0, []]
# منطقه ۲۲ شهر تهران [70, 0, 1670, 3757, 0, 0, 0, 1289, 0, 44.44, []]
# منطقه ۲۲ شهر تهران [96, 6, 1670, 3757, 14, 112, 38, 1488, 70, 100.0, []]

# %%
# !pip install Union

# %%
# !pip install shapely
# Out:
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (1.7.0)
